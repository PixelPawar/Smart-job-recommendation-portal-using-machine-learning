# %% [markdown]
# # Data cleaning
# {   Remove duplicates,
# Handle missing values,
# Remove useless columns,
# Text normalization  }

# %%
import pandas as pd

# %%
df = pd.read_csv("../../data/raw/Fake_Postings.csv")

# %%
df = df.drop_duplicates() #remove dulicate values
df.isnull().sum()  #checking for any missing values
# Out:
# title              0
# description        0
# requirements       0
# company_profile    0
# location           0
# salary_range       0
# employment_type    0
# industry           0
# benefits           0
# fraudulent         0
# dtype: int64

# %%
# creating a text feature
df['job_text'] = (df['title'] + " " +df['description'] + " " +df['requirements'])

# %%
df.to_csv("../../data/processed/clean_jobs.csv", index=False)
