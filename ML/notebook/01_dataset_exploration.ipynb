# %% [markdown]
# # Data understanding

# %%
import pandas as pd
df1 = pd.read_csv("../../data/raw/job_Postings.csv")
df1.head()
# Out:
#                                           title  \
# 0                           Mental health nurse
# 1                     Conference centre manager
# 2                                Engineer, land
# 3                       Forest/woodland manager
# 4  Production designer, theatre/television/film
#
#                                          description  \
# 0  Arm drive court sure vote. Earn $5000/week! Im...
# 1  Government whom its bed go tax tree black. Ear...
# 2  I member discuss follow way there nation. Earn...
# 3  House across wait approach face. Earn $5000/we...
# 4  Case best environmental full finally leader me...
#
#                                         requirements  \
# 0  Basic knowledge in live, no degree required. F...
# 1  Basic knowledge in seek, no degree required. F...
# 2  Basic knowledge in worker, no degree required....
# 3  Basic knowledge in example, no degree required...
# 4  Basic knowledge in smile, no degree required. ...
#
# ...

# %%
df1.shape
# Out:
# (10000, 10)

# %%
df1.columns
# Out:
# Index(['title', 'description', 'requirements', 'company_profile', 'location',
#        'salary_range', 'employment_type', 'industry', 'benefits',
#        'fraudulent'],
#       dtype='str')

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            10000 non-null  str
#  1   description      10000 non-null  str
#  2   requirements     10000 non-null  str
#  3   company_profile  10000 non-null  str
#  4   location         10000 non-null  str
#  5   salary_range     10000 non-null  str
#  6   employment_type  10000 non-null  str
#  7   industry         10000 non-null  str
#  8   benefits         10000 non-null  str
#  9   fraudulent       10000 non-null  int64
# dtypes: int64(1), str(9)
# memory usage: 781.4 KB

# %%
df1.isnull().sum()
# Out:
# title              0
# description        0
# requirements       0
# company_profile    0
# location           0
# salary_range       0
# employment_type    0
# industry           0
# benefits           0
# fraudulent         0
# dtype: int64

# %%
df1.describe()
# Out:
#        fraudulent
# count     10000.0
# mean          1.0
# std           0.0
# min           1.0
# 25%           1.0
# 50%           1.0
# 75%           1.0
# max           1.0
